# %% [markdown]
# PROJECT - 1 CODERS OF DEHLI

# %% [raw]
# Part - 4 :- Implementation of Pages you might like

# %%
#load the data
def load_data(filename):
    with open(filename,"r") as f:
        return json.load(f)

#function to tell pages u might like
def find_pages(user_id,data):
    #dictionary to share the page id
    user_pages = {}
    for user in data["users"]:
        user_pages[user["id"]] = set(user["liked_pages"])

    #if user not found
    if user_id not in user_pages:
        return []

    user_liked_pages = user_pages[user_id]
    page_suggestions = {}

    for other_user,pages in user_pages.items():
        if other_user != user_id:
            shared_pages = user_liked_pages.intersection(pages)
            for page in pages:
                if page not in user_liked_pages:
                    page_suggestions[page] = page_suggestions.get(page,0) + len(shared_pages)
    #sort recommended pages
    """sorted_pages = sorted(page_suggestions.items(),key=lambda x: x[1],reverse=True)
    return [page_id for page_id, _ in sorted_pages]"""

    #if want to get the score of the liked pages then use this
    sorted_pages = sorted(page_suggestions.items(),key=lambda x: x[1],reverse=True)
    return [(page_id,score) for page_id, score in sorted_pages]

#load data
data = load_data("massive_data.json")
user_id = 1
page_rec = find_pages(user_id,data)
print(page_rec)
# Out:
# [(103, 2), (105, 1), (107, 1), (104, 0), (106, 0), (108, 0), (109, 0), (110, 0), (111, 0), (112, 0), (113, 0), (114, 0), (115, 0), (116, 0), (117, 0), (118, 0), (119, 0), (120, 0), (121, 0), (122, 0), (123, 0), (124, 0), (125, 0), (126, 0), (127, 0)]
